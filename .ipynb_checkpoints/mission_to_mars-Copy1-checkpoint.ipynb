# %%
#importing dependancies
from splinter import Browser
from bs4 import BeautifulSoup
#from selenium.webdriver.common.keys import Keys
#from selenium import webdriver
#for twitter api
# Dependencies
import json
import tweepy
#pandas for table scraping
import pandas as pd

# %%
#setting driver up
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
#url for mars news
url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'
browser.visit(url)

# %%
#getting mars news title and paragraph
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
#setting variables
news_title = soup.find('div', class_='content_title').text
news_P = soup.find('div', class_='article_teaser_body').text

# %%
#reviewing data
news_P
# Out:
# 'One of the most intense Martian dust storms ever observed is being studied by a record number of NASA spacecraft.'

# %%
#url for mars image
url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(url)

# %%
#Setting up beautiful soup
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

featured_image_url = soup.find_all('article', class_='carousel_item')
featured_image_url
# Out:
# [<article alt="Speedster Star Shocks the Galaxy" class="carousel_item" style="background-image: url('/spaceimages/images/wallpaper/PIA17843-1920x1200.jpg');">
#  <div class="default floating_text_area ms-layer">
#  <h2 class="category_title">
#  </h2>
#  <h2 class="brand_title">
#  				  FEATURED IMAGE
#  				</h2>
#  <h1 class="media_feature_title">
#  				  Speedster Star Shocks the Galaxy				</h1>
#  <div class="description">
#  </div>
#  <footer>
#  <a class="button fancybox" data-description="The red arc in this infrared image from NASA's Spitzer Space Telescope is a giant shock wave, created by a speeding star known as Kappa Cassiopeiae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/mediumsize/PIA17843_ip.jpg" data-link="/spaceimages/details.php?id=PIA17843" data-title="Speedster Star Shocks the Galaxy" id="full_image">
#  					FULL IMAGE
#  				  </a>
#  </footer>
#  </div>
#  <div class="gradient_container_top"></div>
# ...

# %%
#searching for href
for img in featured_image_url:
    link = img.a['data-fancybox-href']
link
# Out:
# '/spaceimages/images/mediumsize/PIA17843_ip.jpg'

# %%
#setting full path of image
image_path = url + link
image_path
# Out:
# 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars/spaceimages/images/mediumsize/PIA17843_ip.jpg'

# %%
#Mars weather twitter account https://twitter.com/marswxreport?lang=en

# %%
#url for mars image
url = 'https://twitter.com/marswxreport?lang=en'
browser.visit(url)

# %%
#getting mars tweet
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
mars_weather = soup.find('p', class_='TweetTextSize TweetTextSize--normal js-tweet-text tweet-text').text
mars_weather
# Out:
# 'Well, maybe not tomorrow, but the Mars rover Opportunity is sleeping through a massive dust storm until the sun comes out on Mars again, read more at #wral\nhttps://www.wral.com/mars-rover-sleeping-through-massive-dust-storm/17627296/\xa0…pic.twitter.com/Ga2uY1KsGQ'

# %%
asdf = soup.find_all('div', class_='stream')
asdf
# Out:
# [<div class="stream">
#  <ol class="stream-items js-navigable-stream" id="stream-items-id">
#  <li class="js-stream-item stream-item stream-item " data-item-id="1007310899852513280" data-item-type="tweet" data-suggestion-json='{"suggestion_details":{},"tweet_ids":"1007310899852513280","scribe_component":"tweet"}' id="stream-item-tweet-1007310899852513280">
# ...

# %%
#searching for href
for names in asdf:
    name = names.div['data-name']
name
# Out:
# 'Tony Rice'

# %%
#my not need above to get mars_weather
# Import Twitter API Keys
#from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
#auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#auth.set_access_token(access_token, access_token_secret)
#api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
#target_user = "MarsWxReport"

# %%
# Get all tweets from home feed
#public_tweets = api.user_timeline(target_user)

# %%
#public_tweets

# %%
#url for mars table
url = 'https://space-facts.com/mars/'

# %%
tables = pd.read_html(url)
tables

# %%
df = tables[0]
df

# %%
html_table = df.to_html()
html_table

# %%
#DELETE I Dont think i need this
#df.columns = ['Equatorial Diameter', 'Polar Diameter', 'Mass', 'Moons', 
#              'Orbit Distance', 'Orbit Period', 'Surface Temperature', 'First Record', 
#              'Recorded By']
#df.head()

# %%
#high res image
url = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
browser.visit(url)

# %%
soup.findAll('img')

# %%
#browser.click_link_by_text('Cerberus Hemisphere Enhanced')
#browser.click_link_by_href('/search/map/Mars/Viking/cerberus_enhanced')
#browser.click_link_by_partial_href('/search/map/Mars/Viking/cerberus_enhanced')
#browser.find_link_by_text('Cerberus Hemisphere Enhanced').first.click()
browser.click_link_by_partial_text('Cerberus Hemisphere Enhanced')
#need title and imtage_url keys
soup.find

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
sidebar = soup.find('ul', class_='nav-list')

categories = sidebar.find_all('li')

# %%
imgs = soup.find_all("a", class_="itemLink product-item")

# %%
imgs

# %%
imgs = soup.find("div", class_="container")
imgs

# %%
#title_alt = imgs.find('img')['alt'][2]
title_alt = imgs.find_all("img", class_="thumb")
title_alt

# %%
from HTMLParser import HTMLParser
class parser(HTMLParser):
    def handle_starttag(self,tag,attr):
        handle_starttag(img,alt,attr)

# %%
title = []
imge_url = []

for img in imgs:
    title_alt = imgs.find('img')['alt']
    title.append(title_alt)
    #if img:
    #    x = img.find['alt']
    #image = imgs.find('a')['href']
    #imge_url.append(image)
    image = img.get('alt', '')

# %%
titles_and_urls = zip(title, imge_url)
titles_and_urls

# %%
try:
    for title in titles_and_urls:
        browser.click_link_by_partial_text('next')
except ElementDoesNotExist:
    print("Scraping Complete")
